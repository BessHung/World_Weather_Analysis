# %%
# import the dependencies
import pandas as pd
import requests
import numpy as np
from citipy import citipy

from config import weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city from the coordinates
cities =[]

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
print(cities)
# Out:
# ['east london', 'rungata', 'puerto ayora', 'bowen', 'sabha', 'eenhana', 'cape town', 'san cristobal', 'belushya guba', 'wagar', 'tuktoyaktuk', 'carnarvon', 'mataura', 'saint-philippe', 'matamoros', 'raudeberg', 'hobart', 'sucre', 'wajid', 'castro', 'norman wells', 'haines junction', 'hasaki', 'chapais', 'taolanaro', 'hermanus', 'kutum', 'barentsburg', 'sisimiut', 'bilibino', 'tasiilaq', 'poum', 'bengkulu', 'lavrentiya', 'ewa beach', 'pontianak', 'punta arenas', 'namibe', 'cassilandia', 'sao sebastiao do paraiso', 'qaanaaq', 'pisco', 'dikson', 'bulawayo', 'san francisco', 'chuy', 'iqaluit', 'bluff', 'port alfred', 'svetlyy', 'khatanga', 'barrow', 'jamestown', 'alice springs', 'albany', 'butaritari', 'klaksvik', 'asfi', 'buxton', 'busselton', 'sinnamary', 'ushuaia', 'rikitea', 'tiksi', 'lincoln', 'amderma', 'formoso do araguaia', 'kavieng', 'thompson', 'kulhudhuffushi', 'pevek', 'mergui', 'la asuncion', 'kapaa', 'victoria', 'bredasdorp', 'gangotri', 'hithadhoo', 'deputatskiy', 'airai', 'okato', 'neiafu', 'torbay', 'atuona', 'lolua', 'smolenka', 'severo-yeniseyskiy', 'chern', 'murliganj', 'arraial do cabo', 'yellowknife', 'phangnga', 'kaitangata', 'provideniya', 'ribeira grande', 'selikhino', 'saint-francois', 'carutapera', 'saint-joseph', 'saint-ambroise', 'pacific grove', 'sangar', 'morro bay', 'tsihombe', 'inuvik', 'georgetown', 'leningradskiy', 'berlevag', 'nanortalik', 'bud', 'hamilton', 'port-gentil', 'faya', 'mirabad', 'saldanha', 'tocopilla', 'isangel', 'mayumba', 'russell', 'haapiti', 'touros', 'cidreira', 'vaini', 'faanui', 'samusu', 'lebu', 'hilo', 'kiria', 'talawdi', 'antalaha', 'yulara', 'mana', 'strelka', 'storslett', 'boende', 'ponta do sol', 'ouadda', 'miastko', 'jalu', 'souillac', 'grand centre', 'grindavik', 'kaeo', 'luanda', 'vao', 'pudukkottai', 'nova olinda do norte', 'peabiru', 'mar del plata', 'danville', 'panaba', 'lompoc', 'lebanon', 'ngunguru', 'hualmay', 'panacan', 'svobodnyy', 'port elizabeth', 'talnakh', 'illoqqortoormiut', 'salinopolis', 'nantucket', 'hami', 'shchuchye', 'rawson', 'upernavik', 'portland', 'sentyabrskiy', 'ciudad bolivar', 'port hardy', 'jomalig', 'gisborne', 'vardo', 'xichang', 'imbituba', 'san blas', 'nikolskoye', 'biak', 'eureka', 'cherskiy', 'gaomi', 'hofn', 'ancud', 'karakendzha', 'ye', 'kasongo-lunda', 'thinadhoo', 'brae', 'kodiak', 'cabo san lucas', 'talara', 'dingle', 'kamenka', 'sao joao da barra', 'yarada', 'avarua', 'ostrovnoy', 'rancho palos verdes', 'wajima', 'jardim', 'shu', 'ofunato', 'palmer', 'abaza', 'namatanai', 'mahebourg', 'byron bay', 'mount gambier', 'los llanos de aridane', 'fort nelson', 'mys shmidta', 'tilichiki', 'nahan', 'khorixas', 'kazalinsk', 'la ligua', 'sorong', 'jiangyou', 'doha', 'ordzhonikidzevskiy', 'port shepstone', 'nikel', 'kaifeng', 'massa marittima', 'ternate', 'steinbach', 'crateus', 'maceio', 'srednekolymsk', 'ixtapa', 'saint anthony', 'atar', 'grand river south east', 'guerrero negro', 'haukipudas', 'bolungarvik', 'truro', 'bargal', 'lotofaga', 'rocha', 'gasa', 'ilulissat', 'palabuhanratu', 'lagoa', 'khandbari', 'saint-augustin', 'baracoa', 'cockburn town', 'saskylakh', 'kongoussi', 'mingshui', 'asau', 'tabiauea', 'new norfolk', 'koppies', 'la ronge', 'zhangjiakou', 'neka', 'severo-kurilsk', 'sokoto', 'yichang', 'tongchuan', 'the pas', 'belaya gora', 'seltso', 'kieta', 'turayf', 'gizo', 'college', 'mahasamund', 'sitka', 'bubanza', 'esperance', 'buy', 'arya', 'metro', 'moron', 'ust-kuyga', 'hecun', 'kyabram', 'katsuura', 'nalut', 'mackay', 'kupang', 'botwood', 'lata', 'luz', 'naryan-mar', 'narendranagar', 'zhizdra', 'port macquarie', 'robore', 'henties bay', 'gorahun', 'san patricio', 'warrington', 'cherat', 'pemangkat', 'bubaque', 'chokurdakh', 'langnau', 'coffs harbour', 'chengde', 'anadyr', 'changping', 'bakchar', 'wawa', 'puri', 'gerash', 'bethel', 'wanning', 'sandakan', 'qandala', 'awbari', 'muros', 'puerto cabello', 'hun', 'codrington', 'camapua', 'wampusirpi', 'bismil', 'sao filipe', 'vestmannaeyjar', 'kachiry', 'hammerfest', 'ecija', ...

# %%
# Starting URL for weather map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
record_count =1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

for city in cities:
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} | {city}")
    record_count += 1
    
    try:
        # get json data of weather data
        city_weather = requests.get(city_url).json()
        # retrieve the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        Max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_desc = city_weather["weather"][0]["description"]
        country = city_weather['sys']['country']
        # Append the city information into city_data list.
        city_data.append({
             'City':city.title(),
             'Country':country,
             'Lat':city_lat,
             'Lng':city_lng,
             'Max Temp':Max_temp,
             'Humidity':humidity,
             'Cloudiness':city_clouds,
             'Wind Speed':city_wind,
             'Current Description': weather_desc
        })

    except:
        print("City not found. Skipping...")
        pass
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | east london
# Processing Record 2 | rungata
# City not found. Skipping...
# Processing Record 3 | puerto ayora
# Processing Record 4 | bowen
# Processing Record 5 | sabha
# Processing Record 6 | eenhana
# Processing Record 7 | cape town
# Processing Record 8 | san cristobal
# Processing Record 9 | belushya guba
# City not found. Skipping...
# Processing Record 10 | wagar
# Processing Record 11 | tuktoyaktuk
# Processing Record 12 | carnarvon
# Processing Record 13 | mataura
# Processing Record 14 | saint-philippe
# Processing Record 15 | matamoros
# Processing Record 16 | raudeberg
# Processing Record 17 | hobart
# Processing Record 18 | sucre
# Processing Record 19 | wajid
# Processing Record 20 | castro
# Processing Record 21 | norman wells
# Processing Record 22 | haines junction
# Processing Record 23 | hasaki
# Processing Record 24 | chapais
# Processing Record 25 | taolanaro
# City not found. Skipping...
# Processing Record 26 | hermanus
# Processing Record 27 | kutum
# Processing Record 28 | barentsburg
# City not found. Skipping...
# Processing Record 29 | sisimiut
# Processing Record 30 | bilibino
# Processing Record 31 | tasiilaq
# Processing Record 32 | poum
# Processing Record 33 | bengkulu
# Processing Record 34 | lavrentiya
# Processing Record 35 | ewa beach
# Processing Record 36 | pontianak
# Processing Record 37 | punta arenas
# Processing Record 38 | namibe
# Processing Record 39 | cassilandia
# Processing Record 40 | sao sebastiao do paraiso
# Processing Record 41 | qaanaaq
# Processing Record 42 | pisco
# Processing Record 43 | dikson
# Processing Record 44 | bulawayo
# Processing Record 45 | san francisco
# Processing Record 46 | chuy
# Processing Record 47 | iqaluit
# Processing Record 48 | bluff
# Processing Record 49 | port alfred
# Processing Record 50 | svetlyy
# Processing Record 51 | khatanga
# Processing Record 52 | barrow
# Processing Record 53 | jamestown
# Processing Record 54 | alice springs
# Processing Record 55 | albany
# Processing Record 56 | butaritari
# Processing Record 57 | klaksvik
# Processing Record 58 | asfi
# Processing Record 59 | buxton
# Processing Record 60 | busselton
# Processing Record 61 | sinnamary
# Processing Record 62 | ushuaia
# Processing Record 63 | rikitea
# Processing Record 64 | tiksi
# Processing Record 65 | lincoln
# Processing Record 66 | amderma
# City not found. Skipping...
# Processing Record 67 | formoso do araguaia
# City not found. Skipping...
# Processing Record 68 | kavieng
# Processing Record 69 | thompson
# Processing Record 70 | kulhudhuffushi
# Processing Record 71 | pevek
# Processing Record 72 | mergui
# City not found. Skipping...
# Processing Record 73 | la asuncion
# Processing Record 74 | kapaa
# Processing Record 75 | victoria
# Processing Record 76 | bredasdorp
# Processing Record 77 | gangotri
# City not found. Skipping...
# Processing Record 78 | hithadhoo
# Processing Record 79 | deputatskiy
# Processing Record 80 | airai
# Processing Record 81 | okato
# Processing Record 82 | neiafu
# Processing Record 83 | torbay
# Processing Record 84 | atuona
# Processing Record 85 | lolua
# City not found. Skipping...
# Processing Record 86 | smolenka
# Processing Record 87 | severo-yeniseyskiy
# Processing Record 88 | chern
# Processing Record 89 | murliganj
# Processing Record 90 | arraial do cabo
# Processing Record 91 | yellowknife
# Processing Record 92 | phangnga
# Processing Record 93 | kaitangata
# Processing Record 94 | provideniya
# Processing Record 95 | ribeira grande
# Processing Record 96 | selikhino
# Processing Record 97 | saint-francois
# Processing Record 98 | carutapera
# Processing Record 99 | saint-joseph
# Processing Record 100 | saint-ambroise
# Processing Record 101 | pacific grove
# Processing Record 102 | sangar
# Processing Record 103 | morro bay
# Processing Record 104 | tsihombe
# City not found. Skipping...
# Processing Record 105 | inuvik
# Processing Record 106 | georgetown
# Processing Record 107 | leningradskiy
# Processing Record 108 | berlevag
# Processing Record 109 | nanortalik
# Processing Record 110 | bud
# Processing Record 111 | hamilton
# Processing Record 112 | port-gentil
# Processing Record 113 | faya
# Processing Record 114 | mirabad
# Processing Record 115 | saldanha
# Processing Record 116 | tocopilla
# Processing Record 117 | isangel
# Processing Record 118 | mayumba
# Processing Record 119 | russell
# Processing Record 120 | haapiti
# Processing Record 121 | touros
# Processing Record 122 | cidreira
# Processing Record 123 | vaini
# Processing Record 124 | faanui
# Processing Record 125 | samusu
# City not found. Skipping...
# Processing Record 126 | lebu
# Processing Record 127 | hilo
# Processing Record 128 | kiria
# Processing Record 129 | talawdi
# City not found. Skipping...
# Processing Record 130 | antalaha
# Processing Record 131 | yulara
# Processing Record 132 | mana
# Processing Record 133 | strelka
# Processing Record 134 | storslett
# Processing Record 135 | boende
# Processing Record 136 | ponta do sol
# Processing Record 137 | ouadda
# Processing Record 138 | miastko
# Processing Record 139 | jalu
# Processing Record 140 | souillac
# Processing Record 141 | grand centre
# City not found. Skipping...
# Processing Record 142 | grindavik
# Processing Record 143 | kaeo
# Processing Record 144 | luanda
# Processing Record 145 | vao
# Processing Record 146 | pudukkottai
# Processing Record 147 | nova olinda do norte
# Processing Record 148 | peabiru
# Processing Record 149 | mar del plata
# Processing Record 150 | danville
# Processing Record 151 | panaba
# Processing Record 152 | lompoc
# Processing Record 153 | lebanon
# Processing Record 154 | ngunguru
# Processing Record 155 | hualmay
# Processing Record 156 | panacan
# Processing Record 157 | svobodnyy
# Processing Record 158 | port elizabeth
# Processing Record 159 | talnakh
# Processing Record 160 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 161 | salinopolis
# Processing Record 162 | nantucket
# Processing Record 163 | hami
# Processing Record 164 | shchuchye
# City not found. Skipping...
# Processing Record 165 | rawson
# Processing Record 166 | upernavik
# Processing Record 167 | portland
# Processing Record 168 | sentyabrskiy
# City not found. Skipping...
# Processing Record 169 | ciudad bolivar
# Processing Record 170 | port hardy
# Processing Record 171 | jomalig
# City not found. Skipping...
# Processing Record 172 | gisborne
# Processing Record 173 | vardo
# Processing Record 174 | xichang
# Processing Record 175 | imbituba
# Processing Record 176 | san blas
# Processing Record 177 | nikolskoye
# Processing Record 178 | biak
# Processing Record 179 | eureka
# Processing Record 180 | cherskiy
# Processing Record 181 | gaomi
# Processing Record 182 | hofn
# Processing Record 183 | ancud
# Processing Record 184 | karakendzha
# City not found. Skipping...
# Processing Record 185 | ye
# City not found. Skipping...
# Processing Record 186 | kasongo-lunda
# Processing Record 187 | thinadhoo
# Processing Record 188 | brae
# Processing Record 189 | kodiak
# Processing Record 190 | cabo san lucas
# Processing Record 191 | talara
# Processing Record 192 | dingle
# Processing Record 193 | kamenka
# Processing Record 194 | sao joao da barra
# Processing Record 195 | yarada
# Processing Record 196 | avarua
# Processing Record 197 | ostrovnoy
# Processing Record 198 | rancho palos verdes
# Processing Record 199 | wajima
# Processing Record 200 | jardim
# Processing Record 201 | shu
# Processing Record 202 | ofunato
# Processing Record 203 | palmer
# Processing Record 204 | abaza
# Processing Record 205 | namatanai
# Processing Record 206 | mahebourg
# Processing Record 207 | byron bay
# Processing Record 208 | mount gambier
# Processing Record 209 | los llanos de aridane
# Processing Record 210 | fort nelson
# Processing Record 211 | mys shmidta
# City not found. Skipping...
# Processing Record 212 | tilichiki
# Processing Record 213 | nahan
# Processing Record 214 | khorixas
# Processing Record 215 | kazalinsk
# City not found. Skipping...
# Processing Record 216 | la ligua
# Processing Record 217 | sorong
# Processing Record 218 | jiangyou
# Processing Record 219 | doha
# Processing Record 220 | ordzhonikidzevskiy
# Processing Record 221 | port shepstone
# Processing Record 222 | nikel
# Processing Record 223 | kaifeng
# Processing Record 224 | massa marittima
# Processing Record 225 | ternate
# Processing Record 226 | steinbach
# Processing Record 227 | crateus
# Processing Record 228 | maceio
# Processing Record 229 | srednekolymsk
# Processing Record 230 | ixtapa
# Processing Record 231 | saint anthony
# Processing Record 232 | atar
# Processing Record 233 | grand river south east
# City not found. Skipping...
# Processing Record 234 | guerrero negro
# Processing Record 235 | haukipudas
# Processing Record 236 | bolungarvik
# City not found. Skipping...
# Processing Record 237 | truro
# Processing Record 238 | bargal
# City not found. Skipping...
# Processing Record 239 | lotofaga
# Processing Record 240 | rocha
# Processing Record 241 | gasa
# Processing Record 242 | ilulissat
# Processing Record 243 | palabuhanratu
# City not found. Skipping...
# Processing Record 244 | lagoa
# Processing Record 245 | khandbari
# Processing Record 246 | saint-augustin
# Processing Record 247 | baracoa
# Processing Record 248 | cockburn town
# Processing Record 249 | saskylakh
# Processing Record 250 | kongoussi
# Processing Record 251 | mingshui
# Processing Record 252 | asau
# Processing Record 253 | tabiauea
# City not found. Skipping...
# Processing Record 254 | new norfolk
# Processing Record 255 | koppies
# Processing Record 256 | la ronge
# Processing Record 257 | zhangjiakou
# Processing Record 258 | neka
# Processing Record 259 | severo-kurilsk
# Processing Record 260 | sokoto
# Processing Record 261 | yichang
# Processing Record 262 | tongchuan
# Processing Record 263 | the pas
# Processing Record 264 | belaya gora
# Processing Record 265 | seltso
# Processing Record 266 | kieta
# Processing Record 267 | turayf
# Processing Record 268 | gizo
# Processing Record 269 | college
# Processing Record 270 | mahasamund
# Processing Record 271 | sitka
# Processing Record 272 | bubanza
# Processing Record 273 | esperance
# Processing Record 274 | buy
# Processing Record 275 | arya
# Processing Record 276 | metro
# Processing Record 277 | moron
# Processing Record 278 | ust-kuyga
# Processing Record 279 | hecun
# Processing Record 280 | kyabram
# Processing Record 281 | katsuura
# Processing Record 282 | nalut
# Processing Record 283 | mackay
# Processing Record 284 | kupang
# Processing Record 285 | botwood
# Processing Record 286 | lata
# Processing Record 287 | luz
# Processing Record 288 | naryan-mar
# Processing Record 289 | narendranagar
# Processing Record 290 | zhizdra
# Processing Record 291 | port macquarie
# Processing Record 292 | robore
# Processing Record 293 | henties bay
# Processing Record 294 | gorahun
# Processing Record 295 | san patricio
# Processing Record 296 | warrington
# Processing Record 297 | cherat
# Processing Record 298 | pemangkat
# Processing Record 299 | bubaque
# Processing Record 300 | chokurdakh
# Processing Record 301 | langnau
# Processing Record 302 | coffs harbour
# Processing Record 303 | chengde
# Processing Record 304 | anadyr
# Processing Record 305 | changping
# Processing Record 306 | bakchar
# Processing Record 307 | wawa
# Processing Record 308 | puri
# Processing Record 309 | gerash
# Processing Record 310 | bethel
# Processing Record 311 | wanning
# Processing Record 312 | sandakan
# Processing Record 313 | qandala
# Processing Record 314 | awbari
# Processing Record 315 | muros
# Processing Record 316 | puerto cabello
# Processing Record 317 | hun
# Processing Record 318 | codrington
# Processing Record 319 | camapua
# Processing Record 320 | wampusirpi
# City not found. Skipping...
# Processing Record 321 | bismil
# Processing Record 322 | sao filipe
# Processing Record 323 | vestmannaeyjar
# Processing Record 324 | kachiry
# Processing Record 325 | hammerfest
# Processing Record 326 | ecija
# Processing Record 327 | lucapa
# Processing Record 328 | nome
# Processing Record 329 | paamiut
# Processing Record 330 | nizhneyansk
# City not found. Skipping...
# Processing Record 331 | kirakira
# Processing Record 332 | cordoba
# Processing Record 333 | deming
# Processing Record 334 | canon city
# Processing Record 335 | yambio
# Processing Record 336 | shaoxing
# Processing Record 337 | saint george
# Processing Record 338 | orel-izumrud
# Processing Record 339 | aripuana
# Processing Record 340 | padang
# Processing Record 341 | thung song
# Processing Record 342 | halalo
# City not found. Skipping...
# Processing Record 343 | khonuu
# City not found. Skipping...
# Processing Record 344 | vila franca do campo
# Processing Record 345 | la cruz
# Processing Record 346 | mehamn
# Processing Record 347 | bathsheba
# Processing Record 348 | rio gallegos
# Processing Record 349 | kruisfontein
# Processing Record 350 | camacha
# Processing Record 351 | sola
# Processing Record 352 | pangnirtung
# Processing Record 353 | gombe
# Processing Record 354 | san policarpo
# Processing Record 355 | murgab
# Processing Record 356 | prince rupert
# Processing Record 357 | ransang
# Processing Record 358 | sekoma
# Processing Record 359 | kadykchan
# City not found. Skipping...
# Processing Record 360 | mahajanga
# Processing Record 361 | krasnyy oktyabr
# Processing Record 362 | guinticgan
# Processing Record 363 | kununurra
# Processing Record 364 | dharchula
# Processing Record 365 | roma
# Processing Record 366 | praxedis guerrero
# Processing Record 367 | fare
# Processing Record 368 | bardstown
# Processing Record 369 | margate
# Processing Record 370 | tumaco
# Processing Record 371 | pueblo nuevo
# Processing Record 372 | acapulco
# Processing Record 373 | japura
# Processing Record 374 | baghdad
# Processing Record 375 | bacolod
# Processing Record 376 | luan
# Processing Record 377 | hangu
# Processing Record 378 | noumea
# Processing Record 379 | attawapiskat
# City not found. Skipping...
# Processing Record 380 | penapolis
# Processing Record 381 | saint-michel-des-saints
# Processing Record 382 | petropavlovsk-kamchatskiy
# Processing Record 383 | fortuna
# Processing Record 384 | lasa
# Processing Record 385 | vilhena
# Processing Record 386 | brentwood
# Processing Record 387 | methoni
# Processing Record 388 | ossora
# Processing Record 389 | bay saint louis
# Processing Record 390 | jiroft
# City not found. Skipping...
# Processing Record 391 | laguna
# Processing Record 392 | clyde river
# Processing Record 393 | arys
# Processing Record 394 | alexandria
# Processing Record 395 | ust-omchug
# Processing Record 396 | omboue
# Processing Record 397 | kogon
# Processing Record 398 | kintampo
# Processing Record 399 | hambantota
# Processing Record 400 | kitimat
# Processing Record 401 | abnub
# Processing Record 402 | shimoda
# Processing Record 403 | alofi
# Processing Record 404 | pendleton
# Processing Record 405 | tuy hoa
# Processing Record 406 | kiama
# Processing Record 407 | siparia
# Processing Record 408 | sao gabriel da cachoeira
# Processing Record 409 | nova borova
# Processing Record 410 | hihifo
# City not found. Skipping...
# Processing Record 411 | at-bashi
# Processing Record 412 | mount isa
# Processing Record 413 | aksay
# Processing Record 414 | placido de castro
# Processing Record 415 | ilula
# Processing Record 416 | umzimvubu
# City not found. Skipping...
# Processing Record 417 | andros town
# Processing Record 418 | salalah
# Processing Record 419 | beckley
# Processing Record 420 | narsaq
# Processing Record 421 | pindwara
# Processing Record 422 | rakiv lis
# Processing Record 423 | cabra
# Processing Record 424 | saleaula
# City not found. Skipping...
# Processing Record 425 | seoul
# Processing Record 426 | chanute
# Processing Record 427 | sembakung
# Processing Record 428 | barraute
# Processing Record 429 | djibo
# Processing Record 430 | batemans bay
# Processing Record 431 | cedar city
# Processing Record 432 | inhambane
# Processing Record 433 | leh
# Processing Record 434 | loukhi
# Processing Record 435 | newry
# Processing Record 436 | roald
# Processing Record 437 | buqayq
# City not found. Skipping...
# Processing Record 438 | geraldton
# Processing Record 439 | marcona
# City not found. Skipping...
# Processing Record 440 | krasnoselkup
# Processing Record 441 | huarmey
# Processing Record 442 | jiaocheng
# Processing Record 443 | lishui
# Processing Record 444 | phan rang
# City not found. Skipping...
# Processing Record 445 | anloga
# Processing Record 446 | brigantine
# Processing Record 447 | mrirt
# City not found. Skipping...
# Processing Record 448 | buala
# Processing Record 449 | zwedru
# Processing Record 450 | christchurch
# Processing Record 451 | west bay
# Processing Record 452 | westport
# Processing Record 453 | eston
# Processing Record 454 | mayuge
# Processing Record 455 | surt
# Processing Record 456 | wharton
# Processing Record 457 | colombia
# Processing Record 458 | bolivar
# Processing Record 459 | sfantu gheorghe
# Processing Record 460 | alekseyevka
# Processing Record 461 | xingcheng
# Processing Record 462 | hay river
# Processing Record 463 | kabalo
# Processing Record 464 | biltine
# Processing Record 465 | strezhevoy
# Processing Record 466 | lorengau
# Processing Record 467 | abay
# Processing Record 468 | petatlan
# Processing Record 469 | poltavka
# Processing Record 470 | nguiu
# City not found. Skipping...
# Processing Record 471 | longyearbyen
# Processing Record 472 | lalomanu
# City not found. Skipping...
# Processing Record 473 | kon tum
# Processing Record 474 | krasnogorsk
# Processing Record 475 | poso
# Processing Record 476 | araxa
# Processing Record 477 | bodden town
# Processing Record 478 | shingu
# Processing Record 479 | tabou
# Processing Record 480 | yirol
# City not found. Skipping...
# Processing Record 481 | borogontsy
# Processing Record 482 | cochrane
# Processing Record 483 | abu samrah
# Processing Record 484 | catamarca
# Processing Record 485 | nagahama
# Processing Record 486 | belyy yar
# Processing Record 487 | manaus
# Processing Record 488 | harper
# Processing Record 489 | flinders
# Processing Record 490 | nhamunda
# Processing Record 491 | druzhnaya gorka
# Processing Record 492 | peterhead
# Processing Record 493 | shymkent
# Processing Record 494 | singaraja
# Processing Record 495 | nyurba
# Processing Record 496 | warqla
# City not found. Skipping...
# Processing Record 497 | quepos
# Processing Record 498 | ararat
# Processing Record 499 | gracac
# Processing Record 500 | tahta
# Processing Record 501 | san quintin
# Processing Record 502 | olinda
# Processing Record 503 | caravelas
# Processing Record 504 | mandalgovi
# Processing Record 505 | am timan
# Processing Record 506 | conceicao da barra
# Processing Record 507 | sorvag
# City not found. Skipping...
# Processing Record 508 | comodoro rivadavia
# Processing Record 509 | sataua
# City not found. Skipping...
# Processing Record 510 | toliary
# City not found. Skipping...
# Processing Record 511 | songea
# Processing Record 512 | pangody
# Processing Record 513 | belaya kholunitsa
# Processing Record 514 | ziro
# Processing Record 515 | ketchikan
# Processing Record 516 | komsomolets
# Processing Record 517 | kawalu
# Processing Record 518 | ratnagiri
# Processing Record 519 | novyy urengoy
# Processing Record 520 | honiara
# Processing Record 521 | tabarqah
# City not found. Skipping...
# Processing Record 522 | coihaique
# Processing Record 523 | yinchuan
# Processing Record 524 | karratha
# Processing Record 525 | zhaotong
# Processing Record 526 | malanje
# Processing Record 527 | tessalit
# Processing Record 528 | ankazoabo
# Processing Record 529 | mayo
# Processing Record 530 | phalaborwa
# Processing Record 531 | zemio
# Processing Record 532 | tunxi
# City not found. Skipping...
# Processing Record 533 | pericos
# Processing Record 534 | amuntai
# Processing Record 535 | marshfield
# Processing Record 536 | muravlenko
# Processing Record 537 | rudnogorsk
# Processing Record 538 | hoi an
# Processing Record 539 | canala
# Processing Record 540 | komsomolskiy
# Processing Record 541 | ulaangom
# Processing Record 542 | tura
# Processing Record 543 | nanae
# Processing Record 544 | wakkanai
# Processing Record 545 | mlonggo
# Processing Record 546 | san lawrenz
# Processing Record 547 | karagach
# Processing Record 548 | praia
# Processing Record 549 | chumikan
# Processing Record 550 | molina
# Processing Record 551 | richards bay
# Processing Record 552 | ariquemes
# Processing Record 553 | flin flon
# Processing Record 554 | kuah
# Processing Record 555 | port lincoln
# Processing Record 556 | gouyave
# Processing Record 557 | sergeyevka
# Processing Record 558 | agboville
# Processing Record 559 | rincon
# Processing Record 560 | broome
# Processing Record 561 | lazo
# Processing Record 562 | huntsville
# Processing Record 563 | guangyuan
# Processing Record 564 | tucupita
# Processing Record 565 | louisbourg
# City not found. Skipping...
# Processing Record 566 | larsnes
# Processing Record 567 | marsa matruh
# Processing Record 568 | deep river
# Processing Record 569 | itaituba
# Processing Record 570 | zolotinka
# City not found. Skipping...
# Processing Record 571 | soyo
# Processing Record 572 | mamontovo
# Processing Record 573 | kahului
# Processing Record 574 | luwuk
# Processing Record 575 | luis correia
# Processing Record 576 | parrita
# Processing Record 577 | sao borja
# Processing Record 578 | abu jubayhah
# City not found. Skipping...
# Processing Record 579 | soe
# Processing Record 580 | beyneu
# Processing Record 581 | ojo caliente
# Processing Record 582 | kimberley
# Processing Record 583 | maues
# Processing Record 584 | ugoofaaru
# Processing Record 585 | sabang
# Processing Record 586 | zmeinogorsk
# Processing Record 587 | ekhabi
# Processing Record 588 | grand gaube
# Processing Record 589 | fairbanks
# Processing Record 590 | bestobe
# Processing Record 591 | zhigansk
# Processing Record 592 | ribas do rio pardo
# Processing Record 593 | hauterive
# Processing Record 594 | aksarka
# Processing Record 595 | adrar
# Processing Record 596 | gardan diwal
# City not found. Skipping...
# Processing Record 597 | palembang
# Processing Record 598 | andenes
# Processing Record 599 | marsh harbour
# Processing Record 600 | loikaw
# Processing Record 601 | leshukonskoye
# Processing Record 602 | ndola
# Processing Record 603 | egvekinot
# Processing Record 604 | sambava
# Processing Record 605 | oga
# Processing Record 606 | venado
# Processing Record 607 | lixourion
# Processing Record 608 | aneho
# Processing Record 609 | kostomuksha
# Processing Record 610 | gravdal
# Processing Record 611 | aklavik
# Processing Record 612 | bone
# Processing Record 613 | gornja koprivna
# Processing Record 614 | kalmunai
# Processing Record 615 | toora-khem
# Processing Record 616 | scarborough
# Processing Record 617 | yaan
# Processing Record 618 | libreville
# Processing Record 619 | launceston
# Processing Record 620 | vaitape
# Processing Record 621 | itaberaba
# Processing Record 622 | nuuk
# Processing Record 623 | buchanan
# Processing Record 624 | ambilobe
# Processing Record 625 | makakilo city
# Processing Record 626 | lhuntshi
# City not found. Skipping...
# Processing Record 627 | mutoko
# Processing Record 628 | celestun
# Processing Record 629 | nhulunbuy
# Processing Record 630 | karaul
# City not found. Skipping...
# Processing Record 631 | kemijarvi
# Processing Record 632 | sobolevo
# Processing Record 633 | giaginskaya
# Processing Record 634 | pudozh
# Processing Record 635 | rajapur
# Processing Record 636 | kambove
# Processing Record 637 | kavaratti
# Processing Record 638 | hanna
# Processing Record 639 | utica
# Processing Record 640 | kalnibolotskaya
# Processing Record 641 | sumbe
# Processing Record 642 | broken hill
# Processing Record 643 | panukulan
# Processing Record 644 | mareeba
# Processing Record 645 | beringovskiy
# Processing Record 646 | concordia
# Processing Record 647 | waingapu
# Processing Record 648 | stornoway
# Processing Record 649 | belmonte
# Processing Record 650 | selfoss
# Processing Record 651 | campos
# Processing Record 652 | dwarka
# Processing Record 653 | puerto el triunfo
# Processing Record 654 | trairi
# Processing Record 655 | marilia
# Processing Record 656 | mokhsogollokh
# Processing Record 657 | constitucion
# Processing Record 658 | cayenne
# Processing Record 659 | utiroa
# City not found. Skipping...
# Processing Record 660 | barguzin
# Processing Record 661 | xining
# Processing Record 662 | neryungri
# Processing Record 663 | badarganj
# Processing Record 664 | ahuimanu
# Processing Record 665 | ridgecrest
# Processing Record 666 | balaguer
# Processing Record 667 | da lat
# Processing Record 668 | bernalda
# Processing Record 669 | jiaojiang
# Processing Record 670 | paso de los toros
# Processing Record 671 | menongue
# Processing Record 672 | yerbogachen
# Processing Record 673 | zeya
# Processing Record 674 | petrovsk
# Processing Record 675 | yulin
# Processing Record 676 | kamenskoye
# City not found. Skipping...
# Processing Record 677 | nouadhibou
# Processing Record 678 | virginia beach
# Processing Record 679 | nizwa
# Processing Record 680 | taunggyi
# Processing Record 681 | udachnyy
# Processing Record 682 | parras
# City not found. Skipping...
# Processing Record 683 | eldikan
# City not found. Skipping...
# Processing Record 684 | jhargram
# Processing Record 685 | okha
# Processing Record 686 | praia da vitoria
# Processing Record 687 | gobabis
# Processing Record 688 | half moon bay
# Processing Record 689 | lanzhou
# Processing Record 690 | genhe
# Processing Record 691 | beloha
# Processing Record 692 | margherita
# Processing Record 693 | tonantins
# Processing Record 694 | gat
# Processing Record 695 | boguchany
# Processing Record 696 | sao felix do xingu
# Processing Record 697 | ayan
# Processing Record 698 | necochea
# Processing Record 699 | zhigalovo
# Processing Record 700 | karpogory
# Processing Record 701 | vanavara
# Processing Record 702 | vigrestad
# Processing Record 703 | tumannyy
# City not found. Skipping...
# Processing Record 704 | vanimo
# Processing Record 705 | mitu
# Processing Record 706 | presidencia roque saenz pena
# Processing Record 707 | cove
# Processing Record 708 | amahai
# Processing Record 709 | puerto leguizamo
# Processing Record 710 | ambanja
# Processing Record 711 | siniscola
# Processing Record 712 | luderitz
# Processing Record 713 | joniskelis
# Processing Record 714 | ghanzi
# Processing Record 715 | tuatapere
# Processing Record 716 | husavik
# Processing Record 717 | narrabri
# Processing Record 718 | zlatoustovsk
# City not found. Skipping...
# Processing Record 719 | lamar
# Processing Record 720 | scalea
# Processing Record 721 | phan thiet
# Processing Record 722 | amga
# Processing Record 723 | salisbury
# Processing Record 724 | tabuk
# Processing Record 725 | korla
# Processing Record 726 | takaka
# Processing Record 727 | durban
# Processing Record 728 | ahipara
# Processing Record 729 | moose factory
# Processing Record 730 | lufilufi
# Processing Record 731 | tres arroyos
# Processing Record 732 | mikhaylovka
# Processing Record 733 | atlantis
# Processing Record 734 | yabelo
# Processing Record 735 | coquimbo
# Processing Record 736 | menzelinsk
# Processing Record 737 | astana
# Processing Record 738 | hobyo
# Processing Record 739 | verkhnevilyuysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 52.74,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'moderate rain'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.16,
#   'Humidity': 80,
#   'Cloudiness': 67,
#   'Wind Speed': 7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bowen',
#   'Country': 'AU',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 62.82,
#   'Humidity': 88,
#   'Cloudiness': 49,
#   'Wind Speed': 10.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sabha',
#   'Country': 'LY',
#   'Lat': 27.0377,
#   'Lng': 14.4283,
#   'Max Temp': 104.65,
#   'Humidity': 7,
#   'Cloudiness': 2,
#   'Wind Speed': 13.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Eenhana',
#   'Country': 'NA',
#   'Lat': -17.4667,
#   'Lng': 16.3333,
#   'Max Temp': 85.75,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 6.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 54.01,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 82.58,
#   'Humidity': 46,
#   'Cloudiness': 31,
#   'Wind Speed': 7.83,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wagar',
#   'Country': 'SD',
#   'Lat': 16.1525,
#   'Lng': 36.2032,
#   'Max Temp': 90.14,
#   'Humidity': 50,
#   'Cloudiness': 69,
#   'Wind Speed': 1.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'mist'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 48.27,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 45.48,
#   'Humidity': 98,
#   'Cloudiness': 21,
#   'Wind Speed': 2.62,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 71.19,
#   'Humidity': 84,
#   'Cloudiness': 43,
#   'Wind Speed': 11.41,
#   'Current Description': 'light rain'},
#  {'City': 'Matamoros',
#   'Country': 'MX',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 83.1,
#   'Humidity': 37,
#   'Cloudiness': 87,
#   'Wind Speed': 3.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Raudeberg',
#   'Country': 'NO',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 65.98,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 50.25,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sucre',
#   'Country': 'BO',
#   'Lat': -19.0333,
#   'Lng': -65.2627,
#   'Max Temp': 57.85,
#   'Humidity': 48,
#   'Cloudiness': 74,
#   'Wind Speed': 9.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wajid',
#   'Country': 'SO',
#   'Lat': 3.8093,
#   'Lng': 43.2471,
#   'Max Temp': 86.72,
#   'Humidity': 35,
#   'Cloudiness': 99,
#   'Wind Speed': 15.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 56.44,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 57.24,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 66.15,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 72,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 71.38,
#   'Humidity': 91,
#   'Cloudiness': 77,
#   'Wind Speed': 11.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 51.91,
#   'Humidity': 73,
#   'Cloudiness': 32,
#   'Wind Speed': 10.38,
#   'Current Description': 'light rain'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 78.04,
#   'Humidity': 57,
#   'Cloudiness': 78,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 52.7,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 51.76,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 46.69,
#   'Humidity': 70,
#   'Cloudiness': 29,
#   'Wind Speed': 3.15,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 68.86,
#   'Humidity': 66,
#   'Cloudiness': 18,
#   'Wind Speed': 15.1,
#   'Current Description': 'few clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.47,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 37.83,
#   'Humidity': 66,
#   'Cloudiness': 37,
#   'Wind Speed': 6.02,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ewa Beach',
#   'Country': 'US',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 76.95,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Pontianak',
#   'Country': 'ID',
#   'Lat': -0.0333,
#   'Lng': 109.3333,
#   'Max Temp': 75.52,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50.02,
#   'Humidity': 69,
#   'Cloudiness': 94,
#   'Wind Speed': 40.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 65.39,
#   'Humidity': 80,
#   'Cloudiness': 15,
#   'Wind Speed': 14,
#   'Current Description': 'few clouds'},
#  {'City': 'Cassilandia',
#   'Country': 'BR',
#   'Lat': -19.1133,
#   'Lng': -51.7342,
#   'Max Temp': 89.85,
#   'Humidity': 20,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Sebastiao Do Paraiso',
#   'Country': 'BR',
#   'Lat': -20.9169,
#   'Lng': -46.9914,
#   'Max Temp': 82.99,
#   'Humidity': 22,
#   'Cloudiness': 2,
#   'Wind Speed': 4.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 41.79,
#   'Humidity': 71,
#   'Cloudiness': 96,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 63.01,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 45.36,
#   'Humidity': 95,
#   'Cloudiness': 91,
#   'Wind Speed': 13.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bulawayo',
#   'Country': 'ZW',
#   'Lat': -20.15,
#   'Lng': 28.5833,
#   'Max Temp': 66.33,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Current Description': 'clear sky'},
#  {'City': 'San Francisco',
#   'Country': 'US',
#   'Lat': 37.7749,
#   'Lng': -122.4194,
#   'Max Temp': 81.79,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 53.06,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 38.93,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Current Description': 'mist'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 45.81,
#   'Humidity': 82,
#   'Cloudiness': 8,
#   'Wind Speed': 12.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 54.7,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 12.71,
#   'Current Description': 'light rain'},
#  {'City': 'Svetlyy',
#   'Country': 'RU',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 68.05,
#   'Humidity': 73,
#   'Cloudiness': 81,
#   'Wind Speed': 8.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 43,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 32.59,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 82.51,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 42.35,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 91.15,
#   'Humidity': 67,
#   'Cloudiness': 31,
#   'Wind Speed': 8.03,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.95,
#   'Humidity': 74,
#   'Cloudiness': 30,
#   'Wind Speed': 8.37,
#   'Current Description': 'light rain'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 56.32,
#   'Humidity': 88,
#   'Cloudiness': 71,
#   'Wind Speed': 15.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Asfi',
#   'Country': 'MA',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 74.12,
#   'Humidity': 77,
#   'Cloudiness': 16,
#   'Wind Speed': 15.88,
#   'Current Description': 'few clouds'},
#  {'City': 'Buxton',
#   'Country': 'GB',
#   'Lat': 53.2574,
#   'Lng': -1.9098,
#   'Max Temp': 70.16,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 48.09,
#   'Humidity': 78,
#   'Cloudiness': 59,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 85.24,
#   'Humidity': 66,
#   'Cloudiness': 63,
#   'Wind Speed': 8.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 53.22,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 34.52,
#   'Current Description': 'moderate rain'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.43,
#   'Humidity': 81,
#   'Cloudiness': 57,
#   'Wind Speed': 15.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 48.85,
#   'Humidity': 75,
#   'Cloudiness': 54,
#   'Wind Speed': 13.35,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lincoln',
#   'Country': 'US',
#   'Lat': 40.8,
#   'Lng': -96.667,
#   'Max Temp': 92.01,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 80.4,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 12.82,
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 48.36,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kulhudhuffushi',
#   'Country': 'MV',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 82.65,
#   'Humidity': 76,
#   'Cloudiness': 94,
#   'Wind Speed': 17.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 43.07,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 10.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Asuncion',
#   'Country': 'VE',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 73.13,
#   'Humidity': 100,
#   'Cloudiness': 54,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 79.12,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 85.32,
#   'Humidity': 84,
#   'Cloudiness': 85,
#   'Wind Speed': 9.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 52.92,
#   'Humidity': 66,
#   'Cloudiness': 63,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.72,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 54.14,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Current Description': 'light rain'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 56.97,
#   'Humidity': 76,
#   'Cloudiness': 49,
#   'Wind Speed': 3.49,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Okato',
#   'Country': 'NZ',
#   'Lat': -39.2,
#   'Lng': 173.8833,
#   'Max Temp': 53.42,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 19.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neiafu',
#   'Country': 'TO',
#   'Lat': -18.65,
#   'Lng': -173.9833,
#   'Max Temp': 68.68,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 64.76,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 76.87,
#   'Humidity': 74,
#   'Cloudiness': 29,
#   'Wind Speed': 18.16,
#   'Current Description': 'light rain'},
#  {'City': 'Smolenka',
#   'Country': 'RU',
#   'Lat': 52.1352,
#   'Lng': 113.4974,
#   'Max Temp': 57.27,
#   'Humidity': 94,
#   'Cloudiness': 58,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Severo-Yeniseyskiy',
#   'Country': 'RU',
#   'Lat': 60.3725,
#   'Lng': 93.0408,
#   'Max Temp': 57.47,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Current Description': 'light rain'},
#  {'City': 'Chern',
#   'Country': 'RU',
#   'Lat': 53.4523,
#   'Lng': 36.9145,
#   'Max Temp': 69.85,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 7.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Murliganj',
#   'Country': 'IN',
#   'Lat': 25.9,
#   'Lng': 86.9833,
#   'Max Temp': 80.85,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.56,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 57.72,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Phangnga',
#   'Country': 'TH',
#   'Lat': 8.4509,
#   'Lng': 98.5298,
#   'Max Temp': 78.91,
#   'Humidity': 92,
#   'Cloudiness': 37,
#   'Wind Speed': 2.53,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 40.93,
#   'Humidity': 94,
#   'Cloudiness': 41,
#   'Wind Speed': 6.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 40.03,
#   'Humidity': 75,
#   'Cloudiness': 55,
#   'Wind Speed': 0.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 75.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Selikhino',
#   'Country': 'RU',
#   'Lat': 50.3672,
#   'Lng': 137.4996,
#   'Max Temp': 55.62,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 3.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 79.18,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 81.28,
#   'Humidity': 88,
#   'Cloudiness': 50,
#   'Wind Speed': 10.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 70.18,
#   'Humidity': 81,
#   'Cloudiness': 31,
#   'Wind Speed': 6.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Ambroise',
#   'Country': 'CA',
#   'Lat': 48.5501,
#   'Lng': -71.3324,
#   'Max Temp': 88.9,
#   'Humidity': 66,
#   'Cloudiness': 25,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 81.63,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Current Description': 'haze'},
#  {'City': 'Sangar',
#   'Country': 'RU',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': 57.99,
#   'Humidity': 68,
#   'Cloudiness': 8,
#   'Wind Speed': 4.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Morro Bay',
#   'Country': 'US',
#   'Lat': 35.3658,
#   'Lng': -120.8499,
#   'Max Temp': 86.58,
#   'Humidity': 52,
#   'Cloudiness': 84,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Inuvik',
#   'Country': 'CA',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': 56.26,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 83.89,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 39.49,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 53.55,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 47.05,
#   'Humidity': 80,
#   'Cloudiness': 79,
#   'Wind Speed': 9.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 89.11,
#   'Humidity': 67,
#   'Cloudiness': 19,
#   'Wind Speed': 11.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 93.65,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 80.56,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 69.91,
#   'Humidity': 43,
#   'Cloudiness': 59,
#   'Wind Speed': 3.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mirabad',
#   'Country': 'AF',
#   'Lat': 30.4362,
#   'Lng': 61.8383,
#   'Max Temp': 96.48,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 16.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 53.65,
#   'Humidity': 63,
#   'Cloudiness': 5,
#   'Wind Speed': 24.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Tocopilla',
#   'Country': 'CL',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 65.8,
#   'Humidity': 64,
#   'Cloudiness': 28,
#   'Wind Speed': 8.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 68.47,
#   'Humidity': 76,
#   'Cloudiness': 35,
#   'Wind Speed': 15.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mayumba',
#   'Country': 'GA',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 75.72,
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Russell',
#   'Country': 'US',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 89.96,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Haapiti',
#   'Country': 'PF',
#   'Lat': -17.5667,
#   'Lng': -149.8667,
#   'Max Temp': 73.13,
#   'Humidity': 74,
#   'Cloudiness': 53,
#   'Wind Speed': 13.47,
#   'Current Description': 'light rain'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 81.5,
#   'Humidity': 65,
#   'Cloudiness': 53,
#   'Wind Speed': 17.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 56.86,
#   'Humidity': 60,
#   'Cloudiness': 80,
#   'Wind Speed': 9.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 66.36,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.46,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 13.2,
#   'Current Description': 'few clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 54.5,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 71.8,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'light rain'},
#  {'City': 'Kiria',
#   'Country': 'GR',
#   'Lat': 41.1,
#   'Lng': 24.2833,
#   'Max Temp': 86.38,
#   'Humidity': 66,
#   'Cloudiness': 80,
#   'Wind Speed': 1.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 69.53,
#   'Humidity': 90,
#   'Cloudiness': 5,
#   'Wind Speed': 6.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 48.04,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Mana',
#   'Country': 'GF',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 86.49,
#   'Humidity': 63,
#   'Cloudiness': 79,
#   'Wind Speed': 7.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Strelka',
#   'Country': 'RU',
#   'Lat': 58.0728,
#   'Lng': 93.0344,
#   'Max Temp': 60.03,
#   'Humidity': 97,
#   'Cloudiness': 9,
#   'Wind Speed': 2.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Storslett',
#   'Country': 'NO',
#   'Lat': 69.7678,
#   'Lng': 21.0247,
#   'Max Temp': 55.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Boende',
#   'Country': 'CD',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 79.25,
#   'Humidity': 71,
#   'Cloudiness': 83,
#   'Wind Speed': 2.84,
#   'Current Description': 'light rain'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 79.72,
#   'Humidity': 73,
#   'Cloudiness': 52,
#   'Wind Speed': 2.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ouadda',
#   'Country': 'CF',
#   'Lat': 8.0777,
#   'Lng': 22.4007,
#   'Max Temp': 67.77,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Miastko',
#   'Country': 'PL',
#   'Lat': 54.0028,
#   'Lng': 16.9826,
#   'Max Temp': 69.44,
#   'Humidity': 55,
#   'Cloudiness': 66,
#   'Wind Speed': 6.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 103.28,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 15.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 72.36,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 60.57,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Kaeo',
#   'Country': 'NZ',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 47.32,
#   'Humidity': 94,
#   'Cloudiness': 93,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 67.24,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 21.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pudukkottai',
#   'Country': 'IN',
#   'Lat': 10.3833,
#   'Lng': 78.8167,
#   'Max Temp': 84.06,
#   'Humidity': 60,
#   'Cloudiness': 99,
#   'Wind Speed': 6.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nova Olinda Do Norte',
#   'Country': 'BR',
#   'Lat': -3.8881,
#   'Lng': -59.0942,
#   'Max Temp': 101.95,
#   'Humidity': 21,
#   'Cloudiness': 42,
#   'Wind Speed': 3.06,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Peabiru',
#   'Country': 'BR',
#   'Lat': -23.9128,
#   'Lng': -52.3431,
#   'Max Temp': 71.82,
#   'Humidity': 56,
#   'Cloudiness': 88,
#   'Wind Speed': 4.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 48.22,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Danville',
#   'Country': 'US',
#   'Lat': 36.586,
#   'Lng': -79.395,
#   'Max Temp': 94.64,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Panaba',
#   'Country': 'MX',
#   'Lat': 21.2833,
#   'Lng': -88.2667,
#   'Max Temp': 94.78,
#   'Humidity': 39,
#   'Cloudiness': 20,
#   'Wind Speed': 7.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 82.11,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lebanon',
#   'Country': 'US',
#   'Lat': 36.2081,
#   'Lng': -86.2911,
#   'Max Temp': 92.1,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Ngunguru',
#   'Country': 'NZ',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 47.16,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 67.39,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Panacan',
#   'Country': 'PH',
#   'Lat': 9.2463,
#   'Lng': 118.4082,
#   'Max Temp': 80.19,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 0.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svobodnyy',
#   'Country': 'RU',
#   'Lat': 51.4,
#   'Lng': 128.1333,
#   'Max Temp': 61.68,
#   'Humidity': 67,
#   'Cloudiness': 54,
#   'Wind Speed': 4.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 49.1,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 41.2,
#   'Humidity': 93,
#   'Cloudiness': 34,
#   'Wind Speed': 5.95,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 82.42,
#   'Humidity': 82,
#   'Cloudiness': 80,
#   'Wind Speed': 13.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 89.62,
#   'Humidity': 86,
#   'Cloudiness': 88,
#   'Wind Speed': 17.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 86.34,
#   'Humidity': 18,
#   'Cloudiness': 9,
#   'Wind Speed': 7.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 59.88,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 11.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 43.79,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 0.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 87.89,
#   'Humidity': 53,
#   'Cloudiness': 25,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ciudad Bolivar',
#   'Country': 'VE',
#   'Lat': 8.1222,
#   'Lng': -63.5497,
#   'Max Temp': 89.47,
#   'Humidity': 54,
#   'Cloudiness': 68,
#   'Wind Speed': 5.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 57.38,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'mist'},
#  {'City': 'Gisborne',
#   'Country': 'NZ',
#   'Lat': -38.6533,
#   'Lng': 178.0042,
#   'Max Temp': 51.94,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 55.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Xichang',
#   'Country': 'CN',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 68.74,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Imbituba',
#   'Country': 'BR',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 58.89,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Blas',
#   'Country': 'MX',
#   'Lat': 21.5167,
#   'Lng': -105.2667,
#   'Max Temp': 88.14,
#   'Humidity': 58,
#   'Cloudiness': 36,
#   'Wind Speed': 3.6,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 66.02,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.49,
#   'Current Description': 'light rain'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 75.25,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind Speed': 8.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Eureka',
#   'Country': 'US',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 56.01,
#   'Humidity': 69,
#   'Cloudiness': 50,
#   'Wind Speed': 4.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 56.68,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gaomi',
#   'Country': 'CN',
#   'Lat': 36.3833,
#   'Lng': 119.7528,
#   'Max Temp': 73.18,
#   'Humidity': 91,
#   'Cloudiness': 83,
#   'Wind Speed': 5.5,
#   'Current Description': 'light rain'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 57.22,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 51.33,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Kasongo-Lunda',
#   'Country': 'CD',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 85.6,
#   'Humidity': 20,
#   'Cloudiness': 6,
#   'Wind Speed': 1.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 82.72,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 13.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 58.91,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 52.05,
#   'Humidity': 91,
#   'Cloudiness': 35,
#   'Wind Speed': 1.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 86.5,
#   'Humidity': 76,
#   'Cloudiness': 61,
#   'Wind Speed': 3.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Talara',
#   'Country': 'PE',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 72.36,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 77.32,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 79.86,
#   'Humidity': 57,
#   'Cloudiness': 81,
#   'Wind Speed': 5.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 73.49,
#   'Humidity': 77,
#   'Cloudiness': 51,
#   'Wind Speed': 11.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yarada',
#   'Country': 'IN',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 84.52,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'moderate rain'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 69.85,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 64.81,
#   'Humidity': 63,
#   'Cloudiness': 89,
#   'Wind Speed': 7.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rancho Palos Verdes',
#   'Country': 'US',
#   'Lat': 33.7445,
#   'Lng': -118.387,
#   'Max Temp': 90.14,
#   'Humidity': 80,
#   'Cloudiness': 30,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wajima',
#   'Country': 'JP',
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Max Temp': 74.07,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jardim',
#   'Country': 'BR',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 75.96,
#   'Humidity': 42,
#   'Cloudiness': 91,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shu',
#   'Country': 'KZ',
#   'Lat': 43.5983,
#   'Lng': 73.7614,
#   'Max Temp': 74.19,
#   'Humidity': 38,
#   'Cloudiness': 57,
#   'Wind Speed': 3.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ofunato',
#   'Country': 'JP',
#   'Lat': 39.0717,
#   'Lng': 141.7167,
#   'Max Temp': 67.28,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 93.49,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Abaza',
#   'Country': 'RU',
#   'Lat': 52.655,
#   'Lng': 90.0928,
#   'Max Temp': 57.47,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 4.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 78.39,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Current Description': 'moderate rain'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 72.25,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 58.87,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 9.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 46.31,
#   'Humidity': 100,
#   'Cloudiness': 54,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 74.95,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 60.39,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 51.49,
#   'Humidity': 81,
#   'Cloudiness': 69,
#   'Wind Speed': 0.69,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nahan',
#   'Country': 'IN',
#   'Lat': 30.55,
#   'Lng': 77.3,
#   'Max Temp': 78.15,
#   'Humidity': 76,
#   'Cloudiness': 54,
#   'Wind Speed': 4.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Khorixas',
#   'Country': 'NA',
#   'Lat': -20.3667,
#   'Lng': 14.9667,
#   'Max Temp': 68.88,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 12.57,
#   'Current Description': 'clear sky'},
#  {'City': 'La Ligua',
#   'Country': 'CL',
#   'Lat': -32.4524,
#   'Lng': -71.2311,
#   'Max Temp': 51.58,
#   'Humidity': 60,
#   'Cloudiness': 65,
#   'Wind Speed': 6.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 78.31,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind Speed': 4.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jiangyou',
#   'Country': 'CN',
#   'Lat': 31.7667,
#   'Lng': 104.7167,
#   'Max Temp': 71.2,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Doha',
#   'Country': 'QA',
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 102.51,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Ordzhonikidzevskiy',
#   'Country': 'RU',
#   'Lat': 43.8423,
#   'Lng': 41.8964,
#   'Max Temp': 66.25,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Shepstone',
#   'Country': 'ZA',
#   'Lat': -30.7414,
#   'Lng': 30.455,
#   'Max Temp': 60.55,
#   'Humidity': 77,
#   'Cloudiness': 47,
#   'Wind Speed': 33.44,
#   'Current Description': 'light rain'},
#  {'City': 'Nikel',
#   'Country': 'RU',
#   'Lat': 69.4128,
#   'Lng': 30.222,
#   'Max Temp': 57.38,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 10.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaifeng',
#   'Country': 'CN',
#   'Lat': 34.7911,
#   'Lng': 114.3483,
#   'Max Temp': 77.86,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Current Description': 'light rain'},
#  {'City': 'Massa Marittima',
#   'Country': 'IT',
#   'Lat': 43.049,
#   'Lng': 10.8928,
#   'Max Temp': 90.57,
#   'Humidity': 32,
#   'Cloudiness': 13,
#   'Wind Speed': 4.16,
#   'Current Description': 'few clouds'},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 79.7,
#   'Humidity': 80,
#   'Cloudiness': 88,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Steinbach',
#   'Country': 'DE',
#   'Lat': 50.1667,
#   'Lng': 8.5667,
#   'Max Temp': 85.3,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Crateus',
#   'Country': 'BR',
#   'Lat': -5.1783,
#   'Lng': -40.6775,
#   'Max Temp': 97.97,
#   'Humidity': 24,
#   'Cloudiness': 24,
#   'Wind Speed': 7.31,
#   'Current Description': 'few clouds'},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 83.64,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 63.07,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 86.23,
#   'Humidity': 67,
#   'Cloudiness': 76,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 81.1,
#   'Humidity': 44,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 109.56,
#   'Humidity': 10,
#   'Cloudiness': 26,
#   'Wind Speed': 14.43,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 84.65,
#   'Humidity': 56,
#   'Cloudiness': 23,
#   'Wind Speed': 4.94,
#   'Current Description': 'few clouds'},
#  {'City': 'Haukipudas',
#   'Country': 'FI',
#   'Lat': 65.1765,
#   'Lng': 25.3523,
#   'Max Temp': 64.45,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Truro',
#   'Country': 'GB',
#   'Lat': 50.2653,
#   'Lng': -5.0544,
#   'Max Temp': 69.96,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Lotofaga',
#   'Country': 'WS',
#   'Lat': -13.9764,
#   'Lng': -171.8578,
#   'Max Temp': 71.38,
#   'Humidity': 76,
#   'Cloudiness': 17,
#   'Wind Speed': 12.21,
#   'Current Description': 'few clouds'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 54.21,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 4.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Gasa',
#   'Country': 'PS',
#   'Lat': 31.5,
#   'Lng': 34.4667,
#   'Max Temp': 87.87,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 10.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 45.73,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 73.78,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 13.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Khandbari',
#   'Country': 'NP',
#   'Lat': 27.3747,
#   'Lng': 87.2039,
#   'Max Temp': 73.06,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 0.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 62.11,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baracoa',
#   'Country': 'CU',
#   'Lat': 20.3467,
#   'Lng': -74.4958,
#   'Max Temp': 86.07,
#   'Humidity': 65,
#   'Cloudiness': 37,
#   'Wind Speed': 4.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 84.16,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 45.86,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kongoussi',
#   'Country': 'BF',
#   'Lat': 13.3258,
#   'Lng': -1.5347,
#   'Max Temp': 86.86,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mingshui',
#   'Country': 'CN',
#   'Lat': 36.7167,
#   'Lng': 117.5,
#   'Max Temp': 71.04,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 4.09,
#   'Current Description': 'light rain'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 72.52,
#   'Humidity': 73,
#   'Cloudiness': 44,
#   'Wind Speed': 4.07,
#   'Current Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 49.91,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Koppies',
#   'Country': 'ZA',
#   'Lat': -27.2418,
#   'Lng': 27.5742,
#   'Max Temp': 58.93,
#   'Humidity': 26,
#   'Cloudiness': 10,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 55.65,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhangjiakou',
#   'Country': 'CN',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 65.8,
#   'Humidity': 86,
#   'Cloudiness': 7,
#   'Wind Speed': 4.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Neka',
#   'Country': 'IR',
#   'Lat': 36.6508,
#   'Lng': 53.299,
#   'Max Temp': 85.51,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 50.83,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sokoto',
#   'Country': 'NG',
#   'Lat': 13.0609,
#   'Lng': 5.239,
#   'Max Temp': 84.63,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 6.46,
#   'Current Description': 'light rain'},
#  {'City': 'Yichang',
#   'Country': 'CN',
#   'Lat': 30.7144,
#   'Lng': 111.2847,
#   'Max Temp': 72.34,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'light rain'},
#  {'City': 'Tongchuan',
#   'Country': 'CN',
#   'Lat': 35.0806,
#   'Lng': 109.0897,
#   'Max Temp': 64.69,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Current Description': 'light rain'},
#  {'City': 'The Pas',
#   'Country': 'CA',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 55.42,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 16.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': 53.73,
#   'Humidity': 94,
#   'Cloudiness': 78,
#   'Wind Speed': 2.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Seltso',
#   'Country': 'RU',
#   'Lat': 53.3675,
#   'Lng': 34.1,
#   'Max Temp': 70.29,
#   'Humidity': 64,
#   'Cloudiness': 55,
# ...
#   'Max Temp': 86.18,
#   'Humidity': 60,
#   'Cloudiness': 13,
#   'Wind Speed': 17.81,
#   'Current Description': 'few clouds'},
#  {'City': 'Marilia',
#   'Country': 'BR',
#   'Lat': -22.2139,
#   'Lng': -49.9458,
#   'Max Temp': 83.23,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 4.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Mokhsogollokh',
#   'Country': 'RU',
#   'Lat': 61.4681,
#   'Lng': 128.9203,
#   'Max Temp': 66.31,
#   'Humidity': 79,
#   'Cloudiness': 65,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 56.03,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 6.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 86.04,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Barguzin',
#   'Country': 'RU',
#   'Lat': 53.6167,
#   'Lng': 109.6167,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 7,
#   'Wind Speed': 4.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 53.71,
#   'Humidity': 78,
#   'Cloudiness': 86,
#   'Wind Speed': 3.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neryungri',
#   'Country': 'RU',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': 52.47,
#   'Humidity': 86,
#   'Cloudiness': 23,
#   'Wind Speed': 2.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Badarganj',
#   'Country': 'BD',
#   'Lat': 25.674,
#   'Lng': 89.0549,
#   'Max Temp': 81.75,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 76.86,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ridgecrest',
#   'Country': 'US',
#   'Lat': 35.6225,
#   'Lng': -117.6709,
#   'Max Temp': 90.68,
#   'Humidity': 20,
#   'Cloudiness': 12,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Balaguer',
#   'Country': 'ES',
#   'Lat': 41.7912,
#   'Lng': 0.8109,
#   'Max Temp': 104.4,
#   'Humidity': 33,
#   'Cloudiness': 24,
#   'Wind Speed': 8.52,
#   'Current Description': 'few clouds'},
#  {'City': 'Da Lat',
#   'Country': 'VN',
#   'Lat': 11.9465,
#   'Lng': 108.4419,
#   'Max Temp': 61.74,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bernalda',
#   'Country': 'IT',
#   'Lat': 40.4128,
#   'Lng': 16.692,
#   'Max Temp': 94.86,
#   'Humidity': 30,
#   'Cloudiness': 27,
#   'Wind Speed': 5.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jiaojiang',
#   'Country': 'CN',
#   'Lat': 28.6803,
#   'Lng': 121.4428,
#   'Max Temp': 77.83,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Current Description': 'light rain'},
#  {'City': 'Paso De Los Toros',
#   'Country': 'UY',
#   'Lat': -32.8167,
#   'Lng': -56.5167,
#   'Max Temp': 50.34,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 6.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Menongue',
#   'Country': 'AO',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 70.27,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 60.84,
#   'Humidity': 68,
#   'Cloudiness': 53,
#   'Wind Speed': 3.31,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zeya',
#   'Country': 'RU',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 57.85,
#   'Humidity': 82,
#   'Cloudiness': 79,
#   'Wind Speed': 2.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Petrovsk',
#   'Country': 'RU',
#   'Lat': 52.3064,
#   'Lng': 45.3917,
#   'Max Temp': 82.56,
#   'Humidity': 30,
#   'Cloudiness': 17,
#   'Wind Speed': 11.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Yulin',
#   'Country': 'CN',
#   'Lat': 22.6333,
#   'Lng': 110.15,
#   'Max Temp': 79.32,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 71.17,
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 27.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Virginia Beach',
#   'Country': 'US',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp': 94.05,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Nizwa',
#   'Country': 'OM',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 98.55,
#   'Humidity': 23,
#   'Cloudiness': 52,
#   'Wind Speed': 3.15,
#   'Current Description': 'broken clouds'},
#  {'City': 'Taunggyi',
#   'Country': 'MM',
#   'Lat': 20.7833,
#   'Lng': 97.0333,
#   'Max Temp': 65.01,
#   'Humidity': 96,
#   'Cloudiness': 96,
#   'Wind Speed': 3.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Udachnyy',
#   'Country': 'RU',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 62.06,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jhargram',
#   'Country': 'IN',
#   'Lat': 22.45,
#   'Lng': 86.9833,
#   'Max Temp': 84.25,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okha',
#   'Country': 'RU',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 52.79,
#   'Humidity': 87,
#   'Cloudiness': 3,
#   'Wind Speed': 9.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 80.85,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 22.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gobabis',
#   'Country': 'NA',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 68.83,
#   'Humidity': 18,
#   'Cloudiness': 5,
#   'Wind Speed': 13.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 80.58,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lanzhou',
#   'Country': 'CN',
#   'Lat': 36.0564,
#   'Lng': 103.7922,
#   'Max Temp': 60.08,
#   'Humidity': 51,
#   'Cloudiness': 98,
#   'Wind Speed': 5.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Genhe',
#   'Country': 'CN',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': 54.88,
#   'Humidity': 94,
#   'Cloudiness': 83,
#   'Wind Speed': 1.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 66.42,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Margherita',
#   'Country': 'IN',
#   'Lat': 27.2833,
#   'Lng': 95.6833,
#   'Max Temp': 76.59,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tonantins',
#   'Country': 'BR',
#   'Lat': -2.8731,
#   'Lng': -67.8022,
#   'Max Temp': 92.88,
#   'Humidity': 46,
#   'Cloudiness': 76,
#   'Wind Speed': 1.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 87.4,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 9.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Boguchany',
#   'Country': 'RU',
#   'Lat': 58.3814,
#   'Lng': 97.4531,
#   'Max Temp': 58.89,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 101.1,
#   'Humidity': 19,
#   'Cloudiness': 9,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 63.01,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 3.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 51.04,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhigalovo',
#   'Country': 'RU',
#   'Lat': 54.8097,
#   'Lng': 105.1578,
#   'Max Temp': 66.56,
#   'Humidity': 65,
#   'Cloudiness': 93,
#   'Wind Speed': 2.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karpogory',
#   'Country': 'RU',
#   'Lat': 64.0019,
#   'Lng': 44.4451,
#   'Max Temp': 63.03,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'light rain'},
#  {'City': 'Vanavara',
#   'Country': 'RU',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 63.63,
#   'Humidity': 55,
#   'Cloudiness': 78,
#   'Wind Speed': 4.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vigrestad',
#   'Country': 'NO',
#   'Lat': 58.5667,
#   'Lng': 5.7,
#   'Max Temp': 66.96,
#   'Humidity': 81,
#   'Cloudiness': 67,
#   'Wind Speed': 8.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 78.73,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 5.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitu',
#   'Country': 'CO',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 77.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 65.23,
#   'Humidity': 20,
#   'Cloudiness': 76,
#   'Wind Speed': 6.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cove',
#   'Country': 'BJ',
#   'Lat': 7.221,
#   'Lng': 2.3402,
#   'Max Temp': 79.9,
#   'Humidity': 76,
#   'Cloudiness': 89,
#   'Wind Speed': 8.39,
#   'Current Description': 'light rain'},
#  {'City': 'Amahai',
#   'Country': 'ID',
#   'Lat': -3.3333,
#   'Lng': 128.9167,
#   'Max Temp': 77.22,
#   'Humidity': 89,
#   'Cloudiness': 83,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Leguizamo',
#   'Country': 'CO',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 74.26,
#   'Humidity': 96,
#   'Cloudiness': 94,
#   'Wind Speed': 1.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ambanja',
#   'Country': 'MG',
#   'Lat': -13.6833,
#   'Lng': 48.45,
#   'Max Temp': 72.07,
#   'Humidity': 89,
#   'Cloudiness': 72,
#   'Wind Speed': 1.23,
#   'Current Description': 'light rain'},
#  {'City': 'Siniscola',
#   'Country': 'IT',
#   'Lat': 40.5719,
#   'Lng': 9.6922,
#   'Max Temp': 87.35,
#   'Humidity': 43,
#   'Cloudiness': 48,
#   'Wind Speed': 5.06,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 59.56,
#   'Humidity': 63,
#   'Cloudiness': 45,
#   'Wind Speed': 30.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Joniskelis',
#   'Country': 'LT',
#   'Lat': 56.0253,
#   'Lng': 24.1689,
#   'Max Temp': 70.75,
#   'Humidity': 76,
#   'Cloudiness': 49,
#   'Wind Speed': 6.64,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ghanzi',
#   'Country': 'BW',
#   'Lat': -21.5667,
#   'Lng': 21.7833,
#   'Max Temp': 68.99,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 6.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 45.82,
#   'Humidity': 92,
#   'Cloudiness': 11,
#   'Wind Speed': 4.23,
#   'Current Description': 'few clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 55.31,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 6.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Narrabri',
#   'Country': 'AU',
#   'Lat': -30.3167,
#   'Lng': 149.7833,
#   'Max Temp': 55.49,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lamar',
#   'Country': 'US',
#   'Lat': 33.6668,
#   'Lng': -95.5836,
#   'Max Temp': 93.63,
#   'Humidity': 61,
#   'Cloudiness': 56,
#   'Wind Speed': 9.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Scalea',
#   'Country': 'IT',
#   'Lat': 39.813,
#   'Lng': 15.7956,
#   'Max Temp': 97.34,
#   'Humidity': 65,
#   'Cloudiness': 16,
#   'Wind Speed': 0.58,
#   'Current Description': 'few clouds'},
#  {'City': 'Phan Thiet',
#   'Country': 'VN',
#   'Lat': 10.9333,
#   'Lng': 108.1,
#   'Max Temp': 78.4,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Amga',
#   'Country': 'RU',
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp': 61.36,
#   'Humidity': 71,
#   'Cloudiness': 50,
#   'Wind Speed': 1.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Salisbury',
#   'Country': 'GB',
#   'Lat': 51.0693,
#   'Lng': -1.7957,
#   'Max Temp': 70.63,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tabuk',
#   'Country': 'PH',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 74.97,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 85.17,
#   'Humidity': 23,
#   'Cloudiness': 4,
#   'Wind Speed': 4.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Takaka',
#   'Country': 'NZ',
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp': 56.97,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.78,
#   'Current Description': 'light rain'},
#  {'City': 'Durban',
#   'Country': 'ZA',
#   'Lat': -29.8579,
#   'Lng': 31.0292,
#   'Max Temp': 67.12,
#   'Humidity': 73,
#   'Cloudiness': 36,
#   'Wind Speed': 11.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 54.39,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 12.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moose Factory',
#   'Country': 'CA',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 75.2,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Lufilufi',
#   'Country': 'WS',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Max Temp': 71.38,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 11.07,
#   'Current Description': 'few clouds'},
#  {'City': 'Tres Arroyos',
#   'Country': 'AR',
#   'Lat': -38.3739,
#   'Lng': -60.2798,
#   'Max Temp': 53.19,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 7.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Mikhaylovka',
#   'Country': 'RU',
#   'Lat': 50.06,
#   'Lng': 43.2379,
#   'Max Temp': 81.39,
#   'Humidity': 55,
#   'Cloudiness': 77,
#   'Wind Speed': 14.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atlantis',
#   'Country': 'ZA',
#   'Lat': -33.5667,
#   'Lng': 18.4834,
#   'Max Temp': 52.09,
#   'Humidity': 75,
#   'Cloudiness': 6,
#   'Wind Speed': 17,
#   'Current Description': 'clear sky'},
#  {'City': 'Yabelo',
#   'Country': 'ET',
#   'Lat': 4.8833,
#   'Lng': 38.0833,
#   'Max Temp': 68.77,
#   'Humidity': 48,
#   'Cloudiness': 88,
#   'Wind Speed': 5.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 53.33,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Menzelinsk',
#   'Country': 'RU',
#   'Lat': 55.7271,
#   'Lng': 53.1026,
#   'Max Temp': 74.44,
#   'Humidity': 35,
#   'Cloudiness': 4,
#   'Wind Speed': 9.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Astana',
#   'Country': 'KZ',
#   'Lat': 51.1801,
#   'Lng': 71.446,
#   'Max Temp': 55.35,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 17.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.77,
#   'Humidity': 83,
#   'Cloudiness': 7,
#   'Wind Speed': 24.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 61.74,
#   'Humidity': 63,
#   'Cloudiness': 26,
#   'Wind Speed': 2.86,
#   'Current Description': 'scattered clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London      ZA -33.0153   27.9116     52.74        87          75
# 1  Puerto Ayora      EC  -0.7393  -90.3518     75.16        80          67
# 2         Bowen      AU -20.0167  148.2333     62.82        88          49
# 3         Sabha      LY  27.0377   14.4283    104.65         7           2
# 4       Eenhana      NA -17.4667   16.3333     85.75        13           0
#
#    Wind Speed Current Description
# 0       11.50       moderate rain
# 1        7.00       broken clouds
# 2       10.33    scattered clouds
# 3       13.22           clear sky
# 4        6.20           clear sky

# %%
# Create the output file (CSV).
output_file = 'Weather_Database/WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_file, index_label="City_ID")
